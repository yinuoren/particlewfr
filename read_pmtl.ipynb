# %%
import json
import matplotlib.pyplot as plt
from pymoo.problems import get_problem
import numpy as np

# %%
cur_problem = 'dtlz7'
problem = get_problem(cur_problem)
pf = problem.pareto_front()

# %%
with open('results/cosmos/DTLZ7/2023-10-04_04-39-35/train_results.json') as f:
    train_results = json.load(f)
    
theta = train_results['start_0']['epoch_2999']['scores']
theta = np.array(theta)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pf[:,0] , pf[:,1], pf[:,2], c='r', marker='o', alpha = 0.01)
ax.scatter(theta[:, 0], theta[:, 1], theta[:, 2], c='b', marker='x')

elevation = 20
azimuth = 60
ax.view_init(elevation, azimuth)

ax.set_xlabel('$f_1$')
ax.set_ylabel('$f_2$')
ax.set_zlabel('$f_3$')

plt.show()
