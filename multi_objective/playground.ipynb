# %%
import objectives
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
F1 = objectives.ZDT3_1()
F2 = objectives.ZDT3_2()

# %%
x = torch.zeros(30)
x[0] = 0.85
f1 = x[0]
g = 1 + 9 * torch.mean(x[1:]) 
h = 1 - torch.sqrt(f1 / g) - (f1 / g) * torch.sin(10 * np.pi * f1)
f2 = g * h + 1
(f1, f2)
# Out:
# (tensor(0.8500), tensor(0.2280))

# %%
y1, y2 = [], []

for i in range(10000):
    x = torch.rand(30)
    y1.append(F1(x))
    y2.append(F2(x) + 1)

plt.scatter(y1, y2)
